# %% [markdown]
# <a href="https://colab.research.google.com/github/yunuserbas/Geocoding/blob/main/2_GeoCoding_Nominatim_OSM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# Execute the code below :

import requests
link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link).json()
r
# Out:
# [{'place_id': 200000127,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 409895559,
#   'boundingbox': ['37.5110212', '37.5113841', '15.0942789', '15.0969174'],
#   'lat': '37.5112366',
#   'lon': '15.0957499',
#   'display_name': 'Via Pietro Mascagni, Picanello-Ognina-Barriera-Canalicchio, Catania, Sicilia, 95027, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 120742631,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847'],
#   'lat': '37.6091358',
#   'lon': '15.1596388',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 135708126,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128394486,
#   'boundingbox': ['37.6089805', '37.609111', '15.1602847', '15.16103'],
#   'lat': '37.6090903',
#   'lon': '15.1604414',
#   'display_name': 'Via Pietro Mascagni, Santa Caterina, Acireale, Catania, Sicilia, 95024, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 144940640,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'boundingbox': ['37.5673863', '37.5680605', '14.9106504', '14.9109837'],
#   'lat': '37.5676811',
#   'lon': '14.9106709',
#   'display_name': 'Via Pietro Mascagni, Paternò, Catania, Sicilia, 95047, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 135038142,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128391464,
#   'boundingbox': ['37.8731787', '37.8744884', '14.9551124', '14.9563286'],
#   'lat': '37.8738625',
#   'lon': '14.9555742',
#   'display_name': 'Via Pietro Mascagni, Randazzo, Catania, Sicilia, 95036, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 115135839,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 37345033,
#   'boundingbox': ['37.723497', '37.7258149', '15.1784657', '15.1794786'],
#   'lat': '37.7242361',
#   'lon': '15.1789984',
#   'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 155907018,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 211056073,
#   'boundingbox': ['37.5559895', '37.5567121', '14.9169673', '14.9175618'],
#   'lat': '37.5567121',
#   'lon': '14.9169673',
#   'display_name': 'Via Pietro Mascagni, Giaconia, Belpasso, Catania, Sicilia, 95032, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 159605245,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 219951497,
#   'boundingbox': ['37.6498431', '37.6500893', '14.863277', '14.8634543'],
#   'lat': '37.6498431',
#   'lon': '14.863277',
#   'display_name': 'Via Pietro Mascagni, Biancavilla, Catania, Sicilia, 95033, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 129349128,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 105406741,
#   'boundingbox': ['37.6910044', '37.6919085', '15.1028803', '15.1031341'],
#   'lat': '37.6916326',
#   'lon': '15.1030849',
#   'display_name': 'Via Pietro Mascagni, Ballo, Zafferana Etnea, Catania, Sicilia, 95019, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51},
#  {'place_id': 154946932,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 206283540,
#   'boundingbox': ['37.6230119', '37.6248887', '15.0142476', '15.0152742'],
#   'lat': '37.6241385',
#   'lon': '15.0145038',
#   'display_name': 'Via Pietro Mascagni, Nicolosi, Catania, Sicilia, 95030, Italia',
#   'class': 'highway',
#   'type': 'residential',
#   'importance': 0.51}]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 200000127, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 409895559, 'boundingbox': ['37.5110212', '37.5113841', '15.0942789', '15.0969174'], 'lat': '37.5112366', 'lon': '15.0957499', 'display_name': 'Via Pietro Mascagni, Picanello-Ognina-Barriera-Canalicchio, Catania, Sicilia, 95027, Italia', 'class': 'highway', 'type': 'residential', 'importance': 0.51}
# First address longitude : 15.0957499
# First address latitude : 37.5112366

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character, 
# and special characters or accents should be avoided if possible

link_main = 'https://nominatim.openstreetmap.org/?q='
address = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'

link = link_main + address.replace(' ', '+') # It's your turn here. Your goal is to get a link in the right format

print(link + link_end)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,+Catania,+Italy&format=json&limit=1

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API, 
# then makes the request and returns the coordinates :

def API_address(postal_address):
  link_main = 'https://nominatim.openstreetmap.org/?q='
  link_end = '&format=json&limit=1'

  link = link_main + postal_address.replace(' ', '+')
  return (link + link_end)

# %%
# Test it here:
API_address(address)
# Out:
# 'https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,+Catania,+Italy&format=json&limit=1'

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location 
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0ffb2218851f082bb8334665893b9eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0ffb2218851f082bb8334665893b9eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d0ffb2218851f082bb8334665893b9eb = L.map(
#                 &quot;map_d0ffb2218851f082bb8334665893b9eb&quot;,
#                 {
#                     center: [37.5112366, 15.0957499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a7cb8a98f28a0af8b5ebf8e65602798 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d0ffb2218851f082bb8334665893b9eb);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61da4fca8854cb593bafa247b10f7b5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61da4fca8854cb593bafa247b10f7b5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_61da4fca8854cb593bafa247b10f7b5f = L.map(
#                 &quot;map_61da4fca8854cb593bafa247b10f7b5f&quot;,
#                 {
#                     center: [37.5112366, 15.0957499],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb0934afd050fcde84eaf5ad488675bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61da4fca8854cb593bafa247b10f7b5f);
#
#
#             var marker_aa00408c22f0d9d6578fb0629b285bab = L.marker(
#                 [37.5112366, 15.0957499],
#                 {}
#             ).addTo(map_61da4fca8854cb593bafa247b10f7b5f);
#
#
#         var popup_b8b9c6afce132e3336471e3f3069d6b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c5c923cbc4a3bff35d6686cfe7c62b5e = $(`&lt;div id=&quot;html_c5c923cbc4a3bff35d6686cfe7c62b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#             popup_b8b9c6afce132e3336471e3f3069d6b5.setContent(html_c5c923cbc4a3bff35d6686cfe7c62b5e);
#
#
#         marker_aa00408c22f0d9d6578fb0629b285bab.bindPopup(popup_b8b9c6afce132e3336471e3f3069d6b5)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])
                           
restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %%
restaurants['API'] = restaurants['address'].apply(API_address)
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                                                  API
# 0  https://nominatim.openstreetmap.org/?q=Via+Por...
# 1  https://nominatim.openstreetmap.org/?q=Via+Fis...
# 2  https://nominatim.openstreetmap.org/?q=Via+Acq...
# 3  https://nominatim.openstreetmap.org/?q=Via+Por...

# %%
def coordination(link_api):
  m = requests.get(link_api).json()
  lon = m[0]['lon']
  lat = m[0]['lat']
  #return (f'[{lat}, {lon}]')
  return (lat, lon)

# %%
restaurants['coordination'] = restaurants['API'].apply(coordination)
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                                                  API              coordination
# 0  https://nominatim.openstreetmap.org/?q=Via+Por...  (37.5020931, 15.0931951)
# 1  https://nominatim.openstreetmap.org/?q=Via+Fis...   (37.506171, 15.0943223)
# 2  https://nominatim.openstreetmap.org/?q=Via+Acq...  (37.4913312, 15.0758823)
# 3  https://nominatim.openstreetmap.org/?q=Via+Por...  (37.5029335, 15.0930406)

# %%
coord = restaurants['coordination'][0]
m = folium.Map(location=coord, zoom_start = 15)

def geo(restaurants):
  for i in range(len(restaurants['coordination'])):    
    point=restaurants['coordination'][i]    
    folium.Marker(location=point,popup=restaurants['name'][i]).add_to(m)
    

geo(restaurants)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b62c2bc33fc2140e4f2fe7fef5c5978 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b62c2bc33fc2140e4f2fe7fef5c5978&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0b62c2bc33fc2140e4f2fe7fef5c5978 = L.map(
#                 &quot;map_0b62c2bc33fc2140e4f2fe7fef5c5978&quot;,
#                 {
#                     center: [37.5020931, 15.0931951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d79df050f134a5fb83edd92d01f5073c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b62c2bc33fc2140e4f2fe7fef5c5978);
#
#
#             var marker_30f7017a6a4be3142332f84dc355cea5 = L.marker(
#                 [37.5020931, 15.0931951],
#                 {}
#             ).addTo(map_0b62c2bc33fc2140e4f2fe7fef5c5978);
#
#
#         var popup_7b42fe4419be416542b9a0a3a7395c1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_831c28decc19bdf90354ee553fa34b26 = $(`&lt;div id=&quot;html_831c28decc19bdf90354ee553fa34b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964&lt;/div&gt;`)[0];
#             popup_7b42fe4419be416542b9a0a3a7395c1e.setContent(html_831c28decc19bdf90354ee553fa34b26);
#
#
#         marker_30f7017a6a4be3142332f84dc355cea5.bindPopup(popup_7b42fe4419be416542b9a0a3a7395c1e)
#         ;
#
#
#
#
#             var marker_5be91e154bd05038c5efe4ef4bcf3677 = L.marker(
#                 [37.506171, 15.0943223],
#                 {}
#             ).addTo(map_0b62c2bc33fc2140e4f2fe7fef5c5978);
#
#
#         var popup_bbbbbf0dad7ed449d21ca9678ca4f12d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9d755af9ddca485d06838b6c908f8499 = $(`&lt;div id=&quot;html_9d755af9ddca485d06838b6c908f8499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici&lt;/div&gt;`)[0];
#             popup_bbbbbf0dad7ed449d21ca9678ca4f12d.setContent(html_9d755af9ddca485d06838b6c908f8499);
#
#
#         marker_5be91e154bd05038c5efe4ef4bcf3677.bindPopup(popup_bbbbbf0dad7ed449d21ca9678ca4f12d)
#         ;
#
#
#
#
#             var marker_11e2c33aff26734a013f24c8aab89952 = L.marker(
#                 [37.4913312, 15.0758823],
#                 {}
#             ).addTo(map_0b62c2bc33fc2140e4f2fe7fef5c5978);
#
#
#         var popup_7d35f5e6a1f55c89184d004ffaf6bf60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_35d6763b68e4726356364c8352b51a1c = $(`&lt;div id=&quot;html_35d6763b68e4726356364c8352b51a1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta&lt;/div&gt;`)[0];
#             popup_7d35f5e6a1f55c89184d004ffaf6bf60.setContent(html_35d6763b68e4726356364c8352b51a1c);
#
#
#         marker_11e2c33aff26734a013f24c8aab89952.bindPopup(popup_7d35f5e6a1f55c89184d004ffaf6bf60)
#         ;
#
#
#
#
#             var marker_555b7ee92c1e780d61cbf9ff22c42524 = L.marker(
#                 [37.5029335, 15.0930406],
#                 {}
#             ).addTo(map_0b62c2bc33fc2140e4f2fe7fef5c5978);
#
#
#         var popup_24ffa8c54be8b510ad7f2455e9f9be71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2ad710d3bbdfbe8d4f29ec697d034bcc = $(`&lt;div id=&quot;html_2ad710d3bbdfbe8d4f29ec697d034bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House&lt;/div&gt;`)[0];
#             popup_24ffa8c54be8b510ad7f2455e9f9be71.setContent(html_2ad710d3bbdfbe8d4f29ec697d034bcc);
#
#
#         marker_555b7ee92c1e780d61cbf9ff22c42524.bindPopup(popup_24ffa8c54be8b510ad7f2455e9f9be71)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Remarks on the Nominatim API
# As indicated in the quest, there are many resources for geocoding. Most of them are available by registration, and some require a fee.
#
# The Nominatim API is free and without registration. The disadvantage is that it is relatively slow. If you need to use it in the future, remember to store the results so you don't have to run it several times.
#
# For your knowledge, there is also :
# - the **reverse** address API, which allows you to find the nearest postal address using geographic coordinates.
# - the API from a **CSV file** if you have a lot of addresses to geocode
# - the API **GeoJSON** which allows to obtain a geoJSON format of locations to make choropleth maps
#
#
# All the [documentation is available here](https://nominatim.org/release-docs/develop/api/Search/).
